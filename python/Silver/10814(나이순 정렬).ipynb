# %%
# 1차 시도
N = int(input())

# 회원 리스트
list = []

# 회원 정보 입력(나이, 가입 순번, 이름)
for number in range(N):
    age, name = input().split()
    list.append((int(age), number, name))

# 리스트 정렬 - 오름차순
list.sort()

# 회원 리스트 출력
for i in range(len(list)):
    print(list[i][0], list[i][2])

# %% [markdown]
# ![image.png](attachment:image.png)
